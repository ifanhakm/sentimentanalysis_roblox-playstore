# %% [markdown]
# This notebook contains code for scraping Roblox app reviews on the Play Store using `google-play-scrapper` (https://pypi.org/project/google-play-scraper/).

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.3 MB/s eta 0:00:00
# Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
from google_play_scraper import reviews, Sort
import pandas as pd
from google.colab import files

# %% [markdown]
# Take reviews from Roblox in Google Playstore for all stars rating and limit it to 3052 reviews based on newest reviews in Indonesia with English language

# %%
scrapreview, continuation_token = reviews(
    "com.roblox.client",          # ID app
    lang="en",                    # defaults to ‘en’
    country="id",                 # defaults to ‘us’
    sort=Sort.NEWEST,             # defaults to Sort.MOST_RELEVANT
    count=3052,                   # jumlah ulasan yang diinginkan
)

# %%
app_reviews_df = pd.DataFrame(scrapreview)
app_reviews_df.to_csv("/content/roblox_playstore.csv", index=None, header=True)
files.download("roblox_playstore.csv")

# %%
df = pd.read_csv("/content/roblox_playstore.csv")
df
# Out:
#                                   reviewId       userName  \
# 0     a34478e4-b7f0-4e78-9d5a-9dcde8b014d3  A Google user
# 1     00e0814c-a587-47ab-8fe2-125ec476c6fe  A Google user
# 2     9c0a7b64-04e1-4b39-862d-537bcd23e5c9  A Google user
# 3     1d0e9996-6a5a-4a98-ae37-a7c97c202086  A Google user
# 4     d8eb5f06-05e7-4906-a632-73813f143f52  A Google user
# ...                                    ...            ...
# 3047  5c7f224f-7e04-4b77-b8c3-a7fd7bcb7ceb  A Google user
# 3048  16126579-77db-44cb-a12e-1273b51f02f5  A Google user
# 3049  337ce3cc-59df-476b-88fa-75a22c80acc4  A Google user
# 3050  60a14d07-2f32-4668-885e-ba4c8bf254b9  A Google user
# 3051  e4bef653-ea39-4c64-af0a-92d9eb885451  A Google user
#
#                                               userImage  \
# 0     https://play-lh.googleusercontent.com/EGemoI2N...
# 1     https://play-lh.googleusercontent.com/EGemoI2N...
# 2     https://play-lh.googleusercontent.com/EGemoI2N...
# 3     https://play-lh.googleusercontent.com/EGemoI2N...
# 4     https://play-lh.googleusercontent.com/EGemoI2N...
# ...                                                 ...
# 3047  https://play-lh.googleusercontent.com/EGemoI2N...
# 3048  https://play-lh.googleusercontent.com/EGemoI2N...
# 3049  https://play-lh.googleusercontent.com/EGemoI2N...
# 3050  https://play-lh.googleusercontent.com/EGemoI2N...
# 3051  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                                 content  score  thumbsUpCount  \
# 0                                           nice game 🎯      5              0
# 1                                   best game ever made      4              0
# 2                 they should do a update on pls donate      5              0
# 3                    It keeps on removing my accounts 😡      1              0
# 4     brooo roblox is so lag but I love roblox l ❤❤❤...      5              0
# ...                                                 ...    ...            ...
# 3047  THIS GAME IS MY FAVOURITE GAME THIS IS BEST GA...      5              0
# 3048                                         bomboclat🍑      4              0
# 3049                               the best of the best      5              0
# 3050                      amazing 😍😍😍 game ,best ever!!      5              0
# 3051  this app has so much fun this app has so many ...      5              0
#
#      reviewCreatedVersion                   at  replyContent  repliedAt  \
# 0               2.691.868  2025-09-24 14:26:00           NaN        NaN
# 1                     NaN  2025-09-24 14:25:36           NaN        NaN
# 2               2.689.880  2025-09-24 14:24:45           NaN        NaN
# 3                     NaN  2025-09-24 14:24:26           NaN        NaN
# 4               2.691.868  2025-09-24 14:23:48           NaN        NaN
# ...                   ...                  ...           ...        ...
# 3047                  NaN  2025-09-23 08:08:15           NaN        NaN
# 3048            2.691.868  2025-09-23 08:08:12           NaN        NaN
# 3049            2.691.868  2025-09-23 08:08:02           NaN        NaN
# 3050            2.690.721  2025-09-23 08:07:52           NaN        NaN
# 3051                  NaN  2025-09-23 08:07:31           NaN        NaN
#
#      appVersion
# 0     2.691.868
# 1           NaN
# 2     2.689.880
# 3           NaN
# 4     2.691.868
# ...         ...
# 3047        NaN
# 3048  2.691.868
# 3049  2.691.868
# 3050  2.690.721
# 3051        NaN
#
# [3052 rows x 11 columns]
